# %%
import pandas as pd
import numpy as np
import spacy as nlp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataframe from csv using the ID column as index
games = pd.read_csv('../../project/assignment1/games.csv', index_col=0)
games
# Out:
#                                         Title  Release Date
# 0                                  Elden Ring  Feb 25, 2022  \
# 1                                       Hades  Dec 10, 2019
# 2     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                   Undertale  Sep 15, 2015
# 4                               Hollow Knight  Feb 24, 2017
# ...                                       ...           ...
# 1507             Back to the Future: The Game  Dec 22, 2010
# 1508                        Team Sonic Racing  May 21, 2019
# 1509                           Dragon's Dogma  May 22, 2012
# 1510                          Baldur's Gate 3  Oct 06, 2020
# 1511                 The LEGO Movie Videogame  Feb 04, 2014
#
#                                                    Team  Rating Times Listed
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K  \
# 1                                  ['Supergiant Games']     4.3         2.9K
# ...

# %%
#different random EDA meassures
games_shape = games.shape
print(games_shape)
games_info = games.info()
print(games_info)
# Out:
# (1512, 13)
# <class 'pandas.core.frame.DataFrame'>
# Index: 1512 entries, 0 to 1511
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1512 non-null   object
#  1   Release Date       1512 non-null   object
#  2   Team               1511 non-null   object
#  3   Rating             1499 non-null   float64
#  4   Times Listed       1512 non-null   object
#  5   Number of Reviews  1512 non-null   object
#  6   Genres             1512 non-null   object
#  7   Summary            1511 non-null   object
#  8   Reviews            1512 non-null   object
#  9   Plays              1512 non-null   object
#  10  Playing            1512 non-null   object
#  11  Backlogs           1512 non-null   object
#  12  Wishlist           1512 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 165.4+ KB
# None

# %%
print(games.isnull().sum())
#how do we deal with the null datapoints? 1 in team and summary and quite a few in Rating
nan_rating = games[games['Rating'].isnull()]
nan_rating
# Out:
# Title                 0
# Release Date          0
# Team                  1
# Rating               13
# Times Listed          0
# Number of Reviews     0
# Genres                0
# Summary               1
# Reviews               0
# Plays                 0
# Playing               0
# Backlogs              0
# Wishlist              0
# dtype: int64
#                                                   Title     Release Date
# 587                                   Final Fantasy XVI     Jun 22, 2023  \
# 649                                   Death Stranding 2  releases on TBD
# 713                           Final Fantasy VII Rebirth     Dec 31, 2023
# 719                                           Lies of P     Aug 01, 2023
# 726                                               Judas     Mar 31, 2025
# 746   Like a Dragon Gaiden: The Man Who Erased His Name     Dec 31, 2023
# 972           The Legend of Zelda: Tears of the Kingdom     May 12, 2023
# ...

# %%
#furthermore we have 'releases on tbd' in the Release Date column

release_tbd = games[games['Release Date'] == 'releases on TBD']
release_tbd
# Out:
#                                   Title     Release Date
# 644                           Deltarune  releases on TBD  \
# 649                   Death Stranding 2  releases on TBD
# 1252  Elden Ring: Shadow of the Erdtree  releases on TBD
#
#                                                 Team  Rating Times Listed
# 644                                      ['tobyfox']     4.3          313  \
# 649                           ['Kojima Productions']     NaN          105
# 1252  ['FromSoftware', 'Bandai Namco Entertainment']     4.8           18
#
#      Number of Reviews                                            Genres
# 644                313  ['Adventure', 'Indie', 'Music', 'Puzzle', 'RPG']  \
# 649                105                          ['Adventure', 'Shooter']
# 1252                18                              ['Adventure', 'RPG']
#
#                                                 Summary
# 644   UNDERTALE's parallel story, DELTARUNE. Meet ne...  \
# ...

# %%
#min max of plays
max_rating = games['Rating'].max()
min_rating = games['Rating'].min()
print(max_rating)
print(min_rating)
# Out:
# 4.8
# 0.7

# %%
games.describe()
# Out:
#             Rating
# count  1499.000000
# mean      3.719346
# std       0.532608
# min       0.700000
# 25%       3.400000
# 50%       3.800000
# 75%       4.100000
# max       4.800000

# %%
games['Rating'].describe()
# Out:
# count    1499.000000
# mean        3.719346
# std         0.532608
# min         0.700000
# 25%         3.400000
# 50%         3.800000
# 75%         4.100000
# max         4.800000
# Name: Rating, dtype: float64

# %%
#boxplot of the ratings
#with pandas
games.boxplot(column='Rating')
# Out:
# <Axes: >

# %%
#games by year
#release date is an object right now, we need to transfer it into a number
games['Release Date'] = pd.to_datetime(games['Release Date'], errors='coerce')
games['Release Date'].isnull().sum()
# Out:
# 3

# %%
games
games.loc[649,:]
# Out:
# Title                       Death Stranding 2
# Release Date                              NaT
# Team                   ['Kojima Productions']
# Rating                                    NaN
# Times Listed                              105
# Number of Reviews                         105
# Genres               ['Adventure', 'Shooter']
# Summary                                   NaN
# Reviews                                    []
# Plays                                       3
# Playing                                     0
# Backlogs                                  209
# Wishlist                                  644
# Name: 649, dtype: object

# %%
#games per year list?
games['Release Date'].groupby

#plotting the whole thing into a linechart
fig = plt.figure(figsize=(15,8))
ax1 = fig.add_subplot(1,1,1)
ax1.set_xlabel('year')
ax1.set_ylabel('number of games')
ax1.set_title("Games per day since 1980")

games.plot(x='Release Date', kind='line', ax=ax1)
# Out:
# <Axes: title={'center': 'Games per day since 1980'}, xlabel='Release Date', ylabel='number of games'>

# %%
#i wanna look at all of the games that are RPGs so how do I call them from the Genre column and extract the relevant data to a new dataframe?
rpg_games = games[games['Genres'].apply(lambda genres: 'RPG' in genres)]
rpg_games
# Out:
#                                         Title Release Date
# 0                                  Elden Ring   2022-02-25  \
# 1                                       Hades   2019-12-10
# 2     The Legend of Zelda: Breath of the Wild   2017-03-03
# 3                                   Undertale   2015-09-15
# 6                                       Omori   2020-12-25
# ...                                       ...          ...
# 1487                          Lisa the Joyful   2015-08-24
# 1489            Kingdoms of Amalur: Reckoning   2012-02-07
# 1500                        Children of Morta   2019-09-03
# 1509                           Dragon's Dogma   2012-05-22
# 1510                          Baldur's Gate 3   2020-10-06
#
#                                                    Team  Rating Times Listed
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K  \
# 1                                  ['Supergiant Games']     4.3         2.9K
# ...

# %%
rpg_games['Rating'].describe()
rpg_games.boxplot(column='Rating')
# Out:
# <Axes: >

# %%
#indie games vs big publisher games
indie_games = games[games['Genres'].apply(lambda genres: 'Indie' in genres)]
indie_games
publisher_games = games[games['Genres'].apply(lambda genres: 'Indie' not in genres)]
publisher_games
# Out:
#                                         Title Release Date
# 0                                  Elden Ring   2022-02-25  \
# 2     The Legend of Zelda: Breath of the Wild   2017-03-03
# 5                                   Minecraft   2011-11-18
# 7                               Metroid Dread   2021-10-07
# 9                              NieR: Automata   2017-02-23
# ...                                       ...          ...
# 1507             Back to the Future: The Game   2010-12-22
# 1508                        Team Sonic Racing   2019-05-21
# 1509                           Dragon's Dogma   2012-05-22
# 1510                          Baldur's Gate 3   2020-10-06
# 1511                 The LEGO Movie Videogame   2014-02-04
#
#                                                    Team  Rating Times Listed
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K  \
# 2     ['Nintendo', 'Nintendo EPD Production Group No...     4.4         4.3K
# ...
